# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
df = pd.read_csv('coarse-and-fine-grained-ner-dataset.csv')

# %%
df.head()
# Out:
#                                                 Text  \
# 0   grandes feuilles opposées, oblongues-elliptiq...
# 1   feuilles opposées, groupées à l'extrémité des...
# 2   feuilles opposées, obovées oblongues, arrondi...
# 3   arbustes  petites feuilles opposées, groupées...
# 4   arbustes  feuilles opposées ou alternes, obla...
#
#                                       Organ Entities  \
# 0  ['bouton', 'pédicelle', 'corolle', 'tube', 'fe...
# 1  ['limbe', 'style', 'filets', 'rameaux', 'sépal...
# 2  ['corolle', 'limbe', 'ovaire', 'lobes', 'base'...
# 3  ['anthères', 'pétales', 'tube', 'feuilles', 's...
# 4  ['base', 'nervure', 'feuilles', 'arbustes', 'l...
#
#                                  Descriptor Entities  \
# 0  ['fermée', 'pubes-cents', 'cunéiformes', 'vent...
# 1  ['elliptiques', '1 cm de longueur', 'extrorses...
# 2  ['cunéiforme', '10,5 mm de longueur', 'long', ...
# 3  ['secondaires', 'accusé', 'saillantes', 'apicu...
# 4  ['proéminente', 'décurrente', 'alternes', 'obl...
#
#                            Coarse-grained Annotation  \
# 0  [(650, 661, 'DESCRIPTEUR'), (968, 977, 'DESCRI...
# 1  [(609, 618, 'DESCRIPTEUR'), (129, 144, 'DESCRI...
# 2  [(60, 64, 'ORGANE'), (196, 205, 'DESCRIPTEUR')...
# 3  [(949, 959, 'DESCRIPTEUR'), (88, 105, 'DESCRIP...
# 4  [(140, 150, 'DESCRIPTEUR'), (32, 40, 'DESCRIPT...
#
#                              Fine-grained Annotation
# 0  [(650, 661, 'DESCRIPTEUR'), (395, 407, 'DISPOS...
# 1  [(609, 618, 'DESCRIPTEUR'), (73, 80, 'FORME'),...
# 2  [(60, 64, 'ORGANE'), (180, 187, 'ORGANE'), (11...
# 3  [(949, 959, 'DESCRIPTEUR'), (88, 105, 'DESCRIP...
# 4  [(42, 54, 'FORME'), (119, 129, 'FORME'), (1, 9...

# %% [markdown]
# ## First step :
#
# We are going to create tagged words.
# In "Coarse-grained Annotation" we have tuples each one has : (start position, end position, TAG ).
# In text we are going to initialize all words to "O" after processing using the start and end position of the tags, we will split the text into words and map the tags to words. If a word contains any tagged characters, assign the first non-"O" tag to the word.

# %%
import ast

def parse_annotations(annotation_str):
    # Convert string to list of tuples
    return ast.literal_eval(annotation_str)

def generate_ner_tags(text, annotations):
    tags = ["O"] * len(text)
    
    for start, end, label in annotations:
        tags[start] = f"B-{label}"
        for i in range(start + 1, end):
            tags[i] = f"I-{label}"
    
    words = text.split()
    word_tags = []
    current_idx = 0

    for word in words:
        word_start = current_idx
        word_end = current_idx + len(word)
        word_tag = tags[word_start:word_end]
        
        if all(tag == "O" for tag in word_tag):
            word_tags.append((word, "O"))
        else:
            non_o_tags = [tag for tag in word_tag if tag != "O"]
            word_tags.append((word, non_o_tags[0]))
        
        current_idx = word_end + 1  # Move index to the next word

    return word_tags

tagged_sentences = []

for index, row in df.iterrows():
    text = row["Text"]
    annotations = parse_annotations(row["Fine-grained Annotation"])  # Parse annotation string
    word_tags = generate_ner_tags(text, annotations)
    tagged_sentences.append((word_tags))

# %%
tagged_sentences[0]
# Out:
# [('grandes', 'O'),
#  ('feuilles', 'B-ORGANE'),
#  ('opposées,', 'B-DISPOSITION'),
#  ('oblongues-elliptiques', 'B-DESCRIPTEUR'),
#  ('ou', 'O'),
#  ('obovées-elliptiques,', 'B-DESCRIPTEUR'),
#  ('arrondies', 'O'),
#  ('au', 'O'),
#  ('sommet,', 'O'),
#  ('obtuses', 'B-FORME'),
#  ('ou', 'O'),
#  ('cunéiformes', 'B-FORME'),
#  ('à', 'O'),
#  ('la', 'O'),
#  ('base', 'B-ORGANE'),
#  ('limbe', 'B-ORGANE'),
#  ('glabre,', 'I-ORGANE'),
#  ('mesurant', 'O'),
#  ("jusqu'à", 'O'),
#  ('20', 'O'),
#  ('cm', 'I-MESURE'),
#  ('de', 'I-MESURE'),
#  ('longueur', 'I-MESURE'),
#  ('sur', 'I-MESURE'),
#  ('12', 'O'),
#  ('cm', 'I-MESURE'),
#  ('de', 'I-MESURE'),
#  ('largeur', 'I-MESURE'),
#  ('nervure', 'I-MESURE'),
#  ('médiane', 'I-ORGANE'),
#  ('proéminente', 'B-DESCRIPTEUR'),
#  ('dessous,', 'I-DESCRIPTEUR'),
#  ('un', 'O'),
#  ('peu', 'O'),
#  ('saillante', 'B-SURFACE'),
#  ('dessus', 'I-SURFACE'),
#  ('nervures', 'O'),
#  ('secondaires,', 'B-POSITION'),
#  ('5', 'I-POSITION'),
#  ('à', 'O'),
#  ('10', 'O'),
#  ('paires,', 'O'),
#  ('incurvées,', 'B-DESCRIPTEUR'),
#  ('réunies', 'I-DESCRIPTEUR'),
#  ('en', 'O'),
#  ('arceaux', 'O'),
#  ('assez', 'O'),
#  ('loin', 'O'),
#  ('de', 'O'),
#  ('la', 'O'),
#  ('marge,', 'B-ORGANE'),
#  ('saillantes', 'I-ORGANE'),
#  ('dessous,', 'O'),
#  ('bien', 'O'),
#  ('marquées', 'O'),
#  ('dessus,', 'O'),
#  ('anastomosées', 'B-DISPOSITION'),
#  ('à', 'I-DISPOSITION'),
#  ('un', 'I-DISPOSITION'),
#  ('réseau', 'B-ORGANE'),
#  ('de', 'I-ORGANE'),
#  ('nervilles', 'B-ORGANE'),
#  ('à', 'I-ORGANE'),
#  ('grosses', 'I-ORGANE'),
#  ('mailles', 'O'),
#  ('irrégulières,', 'O'),
#  ('finement', 'O'),
#  ('saillant', 'O'),
#  ('dessus', 'O'),
#  ('pétiole', 'B-ORGANE'),
#  ('5-20', 'I-ORGANE'),
#  ('mm', 'O'),
#  ('fleurs', 'O'),
#  ('blanches', 'I-ORGANE'),
#  ('fasciculées', 'I-COULEUR'),
#  ('sur', 'I-DISPOSITION'),
#  ('le', 'I-DISPOSITION'),
#  ('vieux', 'O'),
#  ('bois', 'O'),
#  ('pédicelle', 'B-ORGANE'),
#  ('4-6', 'I-ORGANE'),
#  ('mm,', 'I-ORGANE'),
#  ('glabre', 'O'),
#  ('ou', 'B-SURFACE'),
#  ('légèrement', 'I-SURFACE'),
#  ('pubescent', 'B-SURFACE'),
#  ('galice', 'I-SURFACE'),
#  (':', 'O'),
#  ('4', 'O'),
#  ('sépales', 'O'),
#  ('(2', 'B-ORGANE'),
#  ('+', 'I-ORGANE'),
#  ('2)', 'I-ORGANE'),
#  ('de', 'O'),
#  ('2,5', 'O'),
#  ('mm,', 'O'),
#  ('un', 'O'),
#  ('peu', 'O'),
#  ('pubes-cents', 'B-DESCRIPTEUR'),
#  ('extérieurement', 'I-DESCRIPTEUR'),
#  ('corolle', 'O'),
#  ('à', 'O'),
#  ('8', 'I-ORGANE'),
#  ('lobes', 'I-ORGANE'),
#  ('de', 'O'),
#  ('3', 'B-ORGANE'),
#  ('mm;', 'I-ORGANE'),
#  ('tube', 'O'),
#  ('2', 'O'),
#  ('mm', 'O'),
#  ('ëtamines', 'I-ORGANE'),
#  ('8,', 'O'),
#  ('insérées', 'O'),
#  ('à', 'O'),
#  ('la', 'I-DESCRIPTEUR'),
#  ('gorge;', 'I-DESCRIPTEUR'),
#  ('filets', 'O'),
#  ('3', 'O'),
#  ('mm', 'B-ORGANE'),
#  ('ovaire', 'I-ORGANE'),
#  ('velu,', 'B-ORGANE'),
#  ('à', 'I-ORGANE'),
#  ('4', 'I-ORGANE'),
#  ('loges,', 'B-SURFACE'),
#  ('prolongé', 'B-ORGANE'),
#  ("d'un", 'O'),
#  ('long', 'O'),
#  ('style', 'O'),
#  ('glabre', 'B-ORGANE'),
#  ('dans', 'I-ORGANE'),
#  ('le', 'I-SURFACE'),
#  ('bouton', 'I-SURFACE'),
#  ('la', 'O'),
#  ('corolle,', 'B-ORGANE'),
#  ('étroitement', 'B-ORGANE'),
#  ('fermée,', 'O'),
#  ('laisse', 'B-DESCRIPTEUR'),
#  ('poindre', 'I-DESCRIPTEUR'),
#  ('très', 'I-ORGANE'),
#  ('apparemment', 'O'),
#  ('le', 'O'),
#  ('style', 'O'),
#  ('fruits', 'O'),
#  ('inconnus', 'I-ORGANE'),
#  ('le', 'I-ORGANE'),
#  ('spécimen', 'O'),
#  ('type', 'O'),
#  ('renferme', 'O'),
#  ('une', 'O'),
#  ('seule', 'O'),
#  ('graine', 'O'),
#  ('fusiforme', 'B-ORGANE'),
#  ('non', 'I-ORGANE'),
#  ('carénée,', 'B-FORME'),
#  ('de', 'O'),
#  ('2', 'O'),
#  ('cm', 'B-DESCRIPTEUR'),
#  ('long,', 'I-DESCRIPTEUR'),
#  ('0,6', 'O'),
#  ('large,', 'O'),
#  ('0,6', 'O'),
#  ('épaisseur,', 'O'),
#  ('à', 'O'),
#  ('cicatrice', 'O'),
#  ('oblongue', 'B-ORGANE'),
#  ('coupant', 'I-ORGANE'),
#  ('toute', 'O'),
#  ('la', 'O'),
#  ('face', 'O'),
#  ('ventrale,', 'O'),
#  ('à', 'O'),
#  ('bords', 'B-DESCRIPTEUR'),
#  ('crénelés', 'I-DESCRIPTEUR')]

# %%
X = []
Y = []

for sentence in tagged_sentences:
    X_sentence = []
    Y_sentence = []
    for entity in sentence:
        X_sentence.append(entity[0].lower())
        Y_sentence.append(entity[1])

    X.append(X_sentence)
    Y.append(Y_sentence)

# %%
print("Total number of sentences: {}".format(len(X)))
# Out:
# Total number of sentences: 838

# %%
vocab = set([word.lower() for sentence in X for word in sentence])
num_words = len(set([word.lower() for sentence in X for word in sentence]))

print("Vocabulary size: {}".format(num_words))
# Out:
# Vocabulary size: 12601

# %%
tags = set([word for sentence in Y for word in sentence])
num_tags = len(set([word for sentence in Y for word in sentence]))

print("Total number of tags: {}".format(num_tags))
print("Tags: ", tags)
# Out:
# Total number of tags: 21
# Tags:  {'I-COULEUR', 'B-SURFACE', 'I-POSITION', 'I-SURFACE', 'B-DISPOSITION', 'B-POSITION', 'I-STRUCTURE', 'I-MESURE', 'I-DESCRIPTEUR', 'B-COULEUR', 'I-DISPOSITION', 'I-FORME', 'B-FORME', 'O', 'B-MESURE', 'I-ORGANE', 'B-DESCRIPTEUR', 'B-DEVELOPPEMENT', 'B-ORGANE', 'B-STRUCTURE', 'I-DEVELOPPEMENT'}

# %%
print('sample X: ', X[0], '\n')
print('sample Y: ', Y[0], '\n')
# Out:
# sample X:  ['grandes', 'feuilles', 'opposées,', 'oblongues-elliptiques', 'ou', 'obovées-elliptiques,', 'arrondies', 'au', 'sommet,', 'obtuses', 'ou', 'cunéiformes', 'à', 'la', 'base', 'limbe', 'glabre,', 'mesurant', "jusqu'à", '20', 'cm', 'de', 'longueur', 'sur', '12', 'cm', 'de', 'largeur', 'nervure', 'médiane', 'proéminente', 'dessous,', 'un', 'peu', 'saillante', 'dessus', 'nervures', 'secondaires,', '5', 'à', '10', 'paires,', 'incurvées,', 'réunies', 'en', 'arceaux', 'assez', 'loin', 'de', 'la', 'marge,', 'saillantes', 'dessous,', 'bien', 'marquées', 'dessus,', 'anastomosées', 'à', 'un', 'réseau', 'de', 'nervilles', 'à', 'grosses', 'mailles', 'irrégulières,', 'finement', 'saillant', 'dessus', 'pétiole', '5-20', 'mm', 'fleurs', 'blanches', 'fasciculées', 'sur', 'le', 'vieux', 'bois', 'pédicelle', '4-6', 'mm,', 'glabre', 'ou', 'légèrement', 'pubescent', 'galice', ':', '4', 'sépales', '(2', '+', '2)', 'de', '2,5', 'mm,', 'un', 'peu', 'pubes-cents', 'extérieurement', 'corolle', 'à', '8', 'lobes', 'de', '3', 'mm;', 'tube', '2', 'mm', 'ëtamines', '8,', 'insérées', 'à', 'la', 'gorge;', 'filets', '3', 'mm', 'ovaire', 'velu,', 'à', '4', 'loges,', 'prolongé', "d'un", 'long', 'style', 'glabre', 'dans', 'le', 'bouton', 'la', 'corolle,', 'étroitement', 'fermée,', 'laisse', 'poindre', 'très', 'apparemment', 'le', 'style', 'fruits', 'inconnus', 'le', 'spécimen', 'type', 'renferme', 'une', 'seule', 'graine', 'fusiforme', 'non', 'carénée,', 'de', '2', 'cm', 'long,', '0,6', 'large,', '0,6', 'épaisseur,', 'à', 'cicatrice', 'oblongue', 'coupant', 'toute', 'la', 'face', 'ventrale,', 'à', 'bords', 'crénelés']
#
# sample Y:  ['O', 'B-ORGANE', 'B-DISPOSITION', 'B-DESCRIPTEUR', 'O', 'B-DESCRIPTEUR', 'O', 'O', 'O', 'B-FORME', 'O', 'B-FORME', 'O', 'O', 'B-ORGANE', 'B-ORGANE', 'I-ORGANE', 'O', 'O', 'O', 'I-MESURE', 'I-MESURE', 'I-MESURE', 'I-MESURE', 'O', 'I-MESURE', 'I-MESURE', 'I-MESURE', 'I-MESURE', 'I-ORGANE', 'B-DESCRIPTEUR', 'I-DESCRIPTEUR', 'O', 'O', 'B-SURFACE', 'I-SURFACE', 'O', 'B-POSITION', 'I-POSITION', 'O', 'O', 'O', 'B-DESCRIPTEUR', 'I-DESCRIPTEUR', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANE', 'I-ORGANE', 'O', 'O', 'O', 'O', 'B-DISPOSITION', 'I-DISPOSITION', 'I-DISPOSITION', 'B-ORGANE', 'I-ORGANE', 'B-ORGANE', 'I-ORGANE', 'I-ORGANE', 'O', 'O', 'O', 'O', 'O', 'B-ORGANE', 'I-ORGANE', 'O', 'O', 'I-ORGANE', 'I-COULEUR', 'I-DISPOSITION', 'I-DISPOSITION', 'O', 'O', 'B-ORGANE', 'I-ORGANE', 'I-ORGANE', 'O', 'B-SURFACE', 'I-SURFACE', 'B-SURFACE', 'I-SURFACE', 'O', 'O', 'O', 'B-ORGANE', 'I-ORGANE', 'I-ORGANE', 'O', 'O', 'O', 'O', 'O', 'B-DESCRIPTEUR', 'I-DESCRIPTEUR', 'O', 'O', 'I-ORGANE', 'I-ORGANE', 'O', 'B-ORGANE', 'I-ORGANE', 'O', 'O', 'O', 'I-ORGANE', 'O', 'O', 'O', 'I-DESCRIPTEUR', 'I-DESCRIPTEUR', 'O', 'O', 'B-ORGANE', 'I-ORGANE', 'B-ORGANE', 'I-ORGANE', 'I-ORGANE', 'B-SURFACE', 'B-ORGANE', 'O', 'O', 'O', 'B-ORGANE', 'I-ORGANE', 'I-SURFACE', 'I-SURFACE', 'O', 'B-ORGANE', 'B-ORGANE', 'O', 'B-DESCRIPTEUR', 'I-DESCRIPTEUR', 'I-ORGANE', 'O', 'O', 'O', 'O', 'I-ORGANE', 'I-ORGANE', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANE', 'I-ORGANE', 'B-FORME', 'O', 'O', 'B-DESCRIPTEUR', 'I-DESCRIPTEUR', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORGANE', 'I-ORGANE', 'O', 'O', 'O', 'O', 'O', 'B-DESCRIPTEUR', 'I-DESCRIPTEUR']

# %%
print("Length of first input sequence  : {}".format(len(X[0])))
print("Length of first output sequence : {}".format(len(Y[0])))
# Out:
# Length of first input sequence  : 173
# Length of first output sequence : 173

# %%
word_to_ix = {}

for word in vocab:
  if word not in word_to_ix:
    word_to_ix[word] = len(word_to_ix)

print(word_to_ix)
# Out:
# {'py': 0, 'nouées': 1, 'imitant': 2, '(7-11,': 3, 'vaccinioides': 4, '37836': 5, 'grise,': 6, 'nombreuses,': 7, 'floral,': 8, 'équitantes': 9, '10079': 10, 'ses': 11, 'leurs': 12, 'spatulata,': 13, '1,9-2,5': 14, 'article': 15, 'amplexicaules,': 16, 'staminale;': 17, 'glaucescence': 18, 'pubérulence': 19, '11,5-16': 20, 'verticillées': 21, 'réseau': 22, "d'où": 23, '4e': 24, 'obovoïde': 25, '(-38)': 26, 'détail': 27, '8-10-ovulés;': 28, '(nectaire': 29, 'grimpant,': 30, 'infrutescence': 31, 'deltoïde-lancéolé,': 32, 'triangulaires-acuminés,': 33, 'cymeux,': 34, 'saillies': 35, 'constituant': 36, 'u,': 37, 'ensemble,': 38, '12-22': 39, 'crevassée': 40, 'pombellule': 41, 'éventuellement': 42, 'kew': 43, 'marcottage': 44, 'hirsutum,': 45, 'follicules': 46, 'feuilles),': 47, 'florale': 48, 'néoténique,': 49, '3-3,9': 50, 'sulcalum': 51, 'formations': 52, 'arbustes,': 53, 'cachées': 54, 'franchement': 55, '491)': 56, '0,60': 57, '27,': 58, 'falques': 59, 'subaigu': 60, 'surnuméraires': 61, '29,12': 62, 'sont': 63, 'peltée': 64, 'microsporo-phylles': 65, 'terrestres,': 66, 'denticulée-serrulée,': 67, '(2,8-)4-9': 68, '3,5-7,8': 69, '0,3-1': 70, 'subglabres': 71, 'floralis': 72, '3001': 73, 'moindre': 74, 'diversifolia)': 75, 'campanulé-étoilé,': 76, 'stipitée': 77, 'bientot': 78, 'evoluío': 79, 'pubérùlente,': 80, 'fertiles,': 81, 'vigueur': 82, 'longa': 83, 'délicates': 84, 'obové,parfois': 85, 'davantage': 86, 'douteuse': 87, 'striée,': 88, 'tétramères': 89, 'accrescents': 90, 'tessellée': 91, 'rubigineux': 92, 'porté': 93, 'fïmbriés,': 94, '(30-)40-50': 95, 'wyndham': 96, 'rougeâtres': 97, 'présentant': 98, 'gris-brun': 99, 'jeunes,': 100, '378': 101, 'carlottae': 102, 'primordiale': 103, '12paires': 104, 'endroit': 105, "l'hypanthium,": 106, '0,8-2,5(-4)': 107, 'coniques': 108, 'réduites': 109, 'inflorescen-tiels': 110, 'géniculé);': 111, 'tomentelleux': 112, '10-35': 113, 'tomen-tellum': 114, "l'an-thèse": 115, 'floraison': 116, '622,': 117, 'poussière,': 118, 'sagittées': 119, 'obovés': 120, 'dents,': 121, 'appliquées': 122, "s'épanouissant": 123, 'connue,': 124, 'blanc-grisâtres': 125, 'orthotropes,': 126, 'tanianum': 127, 'nervurées': 128, 'fausse': 129, 'striés-anguleux,': 130, '27322': 131, 'buissormant': 132, '2-3-denté': 133, "s'enroulent": 134, 'cellules': 135, 'solitaires': 136, 'orbiculaires-déprimées,': 137, '1,1-1,3': 138, 'acuminées,': 139, 'distinctif': 140, '7,5-12': 141, 'poilues,': 142, 'échantillon': 143, 'violacée,': 144, 'lemeux': 145, '0,4-2': 146, 'ellipsoïdales,': 147, 'jusque': 148, 'faciales;': 149, 'colonnes': 150, 'oblongues-falciformes;': 151, 'légères': 152, 'surmonte': 153, 'bisexués': 154, 'totalité': 155, 'pendants,': 156, 'translucides': 157, 'adaxial,': 158, 'protologue': 159, 'arrivant': 160, '29': 161, 'région': 162, 'obtusiuscule': 163, 'apparentes,': 164, 'pubérulents,': 165, 'bien': 166, 'atténuée-tronquée': 167, 'ver-dâtre,': 168, 'remarque': 169, 'au-d,essus': 170, 'folioles;': 171, 'subérisation': 172, 'enchevêtrées,': 173, '1-3(4)': 174, 'inerme,': 175, '1,2-3': 176, 'ripicole,': 177, '5-10(-14),': 178, 'autrement': 179, 'passages': 180, 'pedicello': 181, "l'exemple": 182, '(l-)3-4': 183, 'sillonnée;': 184, 'après': 185, 'totale': 186, 'hypanthium': 187, '(syllabus': 188, 'buxifolia': 189, 'pustuleux,': 190, 'verruqueuse': 191, 'ceylan': 192, '2-30': 193, 'dos,': 194, 'denses,': 195, '3527),': 196, 'velouté': 197, 'ramifiées': 198, '(ressemblant': 199, 'capillaceum': 200, '(1,27-)': 201, '(souvent': 202, 'marques': 203, 'subapprimés': 204, "d'araucaria": 205, 'correspond': 206, '59,': 207, 'hémisphériques,': 208, 'lxl': 209, 'baumann': 210, 'naviculi-formes': 211, 'clavoncule,': 212, 'cordé-sagitté': 213, 'maturité': 214, '(seemann': 215, 'â,': 216, 'terminée': 217, '(1-3,': 218, 'hallé': 219, 'médiane),': 220, 'sinuées-dentées': 221, 'déportées': 222, 'revêtement': 223, 'cuticu-laire': 224, 'périantlie': 225, '(oblique)': 226, '41393)': 227, 'pointe),': 228, 'rouges': 229, 'micros-cop ...

# %%
tag_to_ix = {}

for tag in tags:
  tag_to_ix[tag] = len(tag_to_ix)

print(tag_to_ix)
# Out:
# {'I-COULEUR': 0, 'B-SURFACE': 1, 'I-POSITION': 2, 'I-SURFACE': 3, 'B-DISPOSITION': 4, 'B-POSITION': 5, 'I-STRUCTURE': 6, 'I-MESURE': 7, 'I-DESCRIPTEUR': 8, 'B-COULEUR': 9, 'I-DISPOSITION': 10, 'I-FORME': 11, 'B-FORME': 12, 'O': 13, 'B-MESURE': 14, 'I-ORGANE': 15, 'B-DESCRIPTEUR': 16, 'B-DEVELOPPEMENT': 17, 'B-ORGANE': 18, 'B-STRUCTURE': 19, 'I-DEVELOPPEMENT': 20}

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long, device = 'cuda')

# %%
from sklearn.model_selection import train_test_split

SPLIT_SIZE = 0.2

# split entire data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=SPLIT_SIZE, random_state=4)

# split training data into training and validation sets
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=SPLIT_SIZE, random_state=4)

# print number of samples in each set
print("TRAINING DATA")
print('Number of sequences: {}'.format(len(X_train)))
print("-"*50)
print("TESTING DATA")
print('Number of sequences: {}'.format(len(X_test)))
print("-"*50)
print("VALIDATION DATA")
print('Number of sequences: {}'.format(len(X_val)))
# Out:
# TRAINING DATA
# Number of sequences: 536
# --------------------------------------------------
# TESTING DATA
# Number of sequences: 168
# --------------------------------------------------
# VALIDATION DATA
# Number of sequences: 134

# %%
class RNN(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(RNN, self).__init__()

        self.hidden_size = hidden_size

        self.i2h = nn.Linear(input_size, hidden_size)
        self.h2h = nn.Linear(hidden_size, hidden_size)
        self.h2o = nn.Linear(hidden_size, output_size)

    def forward(self, sentence):
        output = []
        hidden = self.initHidden()
        for input in sentence:
          hidden = F.tanh(self.i2h(input) + self.h2h(hidden))
          out = self.h2o(hidden)
          output += out
        output = torch.stack(output)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, self.hidden_size, device = 'cuda')

# %%
class GRU(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(GRU, self).__init__()

        self.hidden_size = hidden_size


        self.x2z = nn.Linear(input_size, hidden_size)
        self.h2z = nn.Linear(hidden_size, hidden_size)
        self.h2r = nn.Linear(hidden_size, hidden_size)
        self.x2r = nn.Linear(input_size, hidden_size)
        self.h2h = nn.Linear(hidden_size, hidden_size)
        self.x2h = nn.Linear(input_size, hidden_size)
        self.h2o = nn.Linear(hidden_size, output_size)


    def forward(self, sentence):
        output = []
        hidden = self.initHidden()
        for input in sentence:
          z = F.sigmoid(self.x2z(input) + self.h2z(hidden))
          r= F.sigmoid(self.x2r(input) + self.h2r(hidden))
          hidden1= F.tanh(r*(self.h2h(hidden))+self.x2h(input))
          hidden= (1-z)*(hidden)+ z*(hidden1)
          out = self.h2o(hidden)
          output += out
        output = torch.stack(output)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, self.hidden_size, device = 'cuda')

# %%
class POSTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size):
        super(POSTagger, self).__init__()
        self.hidden_dim = hidden_dim

        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        self.GRU = GRU(embedding_dim, hidden_dim, tagset_size)


    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        tag_scores, _ = self.GRU(embeds)
        return tag_scores

# %%
EMBEDDING_DIM = 64
HIDDEN_DIM = 32
EPOCHS = 50

# %%
model = POSTagger(EMBEDDING_DIM, HIDDEN_DIM, num_words, num_tags)
model.cuda()
# Out:
# POSTagger(
#   (word_embeddings): Embedding(12601, 64)
#   (GRU): GRU(
#     (x2z): Linear(in_features=64, out_features=32, bias=True)
#     (h2z): Linear(in_features=32, out_features=32, bias=True)
#     (h2r): Linear(in_features=32, out_features=32, bias=True)
#     (x2r): Linear(in_features=64, out_features=32, bias=True)
#     (h2h): Linear(in_features=32, out_features=32, bias=True)
#     (x2h): Linear(in_features=64, out_features=32, bias=True)
#     (h2o): Linear(in_features=32, out_features=21, bias=True)
#   )
# )

# %%
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# See what the scores are before training
# Note that element i,j of the output is the score for tag j for word i.
# torch.no_grad() disables gradient calculation when the model is used for inference

with torch.no_grad():
    inputs = prepare_sequence(X_train[0], word_to_ix)
    tag_scores = model(inputs)
    print(tag_scores)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[32], line 6
#       1 # See what the scores are before training
#       2 # Note that element i,j of the output is the score for tag j for word i.
#       3 # torch.no_grad() disables gradient calculation when the model is used for inference
#       5 with torch.no_grad():
# ----> 6     inputs = prepare_sequence(X_train[0], word_to_ix)
#       7     tag_scores = model(inputs)
#       8     print(tag_scores)
#
# Cell In[15], line 3, in prepare_sequence(seq, to_ix)
#       1 def prepare_sequence(seq, to_ix):
#       2     idxs = [to_ix[w] for w in seq]
# ----> 3     return torch.tensor(idxs, dtype=torch.long, device = 'cuda')
#
# File c:\Users\zaid2\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\cuda\__init__.py:310, in _lazy_init()
#     305     raise RuntimeError(
#     306         "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     307         "multiprocessing, you must use the 'spawn' start method"
#     308     )
#     309 if not hasattr(torch._C, "_cuda_getDeviceCount"):
# --> 310     raise AssertionError("Torch not compiled with CUDA enabled")
#     311 if _cudart is None:
#     312     raise AssertionError(
#     313         "libcudart functions unavailable. It looks like you have a broken build?"
#     314     )
#
# AssertionError: Torch not compiled with CUDA enabled
